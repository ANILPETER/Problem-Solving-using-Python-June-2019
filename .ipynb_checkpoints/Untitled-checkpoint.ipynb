# %%
import pandas as pd
# Reading CSV files

filepath='DataFiles/AppleStore.csv'

AppleStore=pd.read_csv(filepath)

AppleStore
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %%
AppleStore.values[1][6]
# Out:
# 161065

# %%
AppleStore.groupby(['user_rating']).mean()
# Out:
#               Unnamed: 0            id    size_bytes     price  \
# user_rating
# 0.0          6465.852530  1.007350e+09  1.545463e+08  1.080129
# 1.0          6109.431818  9.665681e+08  6.311240e+07  1.926591
# 1.5          5802.428571  9.566616e+08  6.397966e+07  1.208929
# 2.0          5457.301887  9.042506e+08  8.878507e+07  1.155755
# 2.5          4587.637755  8.457130e+08  1.238298e+08  1.103214
# 3.0          4791.159269  8.418089e+08  1.694169e+08  1.288068
# 3.5          4305.857550  8.087262e+08  2.044705e+08  1.757436
# 4.0          4456.072571  8.332178e+08  2.383879e+08  2.209865
# 4.5          4278.417199  8.330329e+08  2.163224e+08  1.802110
# 5.0          5439.268293  9.249921e+08  1.574089e+08  1.645589
#
#              rating_count_tot  rating_count_ver  user_rating_ver  \
# user_rating
# 0.0                  0.000000          0.000000         0.000000
# 1.0                 29.568182         17.204545         0.977273
# ...

# %%
AppleStore.groupby(['prime_genre']).mean()
# Out:
#                     Unnamed: 0            id    size_bytes     price  \
# prime_genre
# Book               5658.276786  9.435737e+08  1.788206e+08  1.790536
# Business           3144.631579  6.934696e+08  6.416849e+07  5.116316
# Catalogs           5147.500000  9.521081e+08  5.018163e+07  0.799000
# Education          4095.317881  8.169410e+08  1.804242e+08  4.028234
# Entertainment      4857.740187  8.507593e+08  1.014787e+08  0.889701
# Finance            3281.096154  7.232960e+08  7.823586e+07  0.421154
# Food & Drink       3425.650794  7.313079e+08  7.759500e+07  1.552381
# Games              5490.717245  9.351898e+08  2.836583e+08  1.432923
# Health & Fitness   3309.444444  7.313714e+08  9.010664e+07  1.916444
# Lifestyle          4557.326389  8.270774e+08  6.230647e+07  0.885417
# Medical            3356.391304  7.458997e+08  3.763890e+08  8.776087
# Music              3492.514493  7.566649e+08  1.096356e+08  4.835435
# ...

# %%
m=AppleStore.groupby(['price']).mean().filter(items=['price','user_rating'],axis=0)
y=AppleStore.groupby(['prime_genre','price']).mean()

y.iloc[:]
# Out:
#                     Unnamed: 0            id    size_bytes  rating_count_tot  \
# prime_genre price
# Book        0.00   6219.348485  9.912704e+08  5.945220e+07       8498.333333
#             0.99   5586.000000  8.946131e+08  4.057984e+07          5.500000
#             1.99   5723.285714  9.202816e+08  1.045543e+08        224.714286
#             2.99   3942.444444  8.102705e+08  3.286924e+08         79.000000
#             3.99   5192.076923  9.505642e+08  2.555211e+08         39.384615
#             4.99   3640.000000  9.244556e+08  5.119181e+08          0.000000
#             5.99   5475.444444  8.815453e+08  6.574934e+08        877.000000
#             6.99    451.000000  3.691116e+08  4.047974e+07        114.000000
#             9.99    971.000000  4.445531e+08  1.257708e+08       1685.000000
#             27.99  3523.000000  9.141895e+08  2.334250e+09        649.000000
# Business    0.00   3875.600000  7.792654e+08  7.409505e+07       6367.800000
# ...

# %%
AppleStore.filter(like='Games', axis=0)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, track_name, size_bytes, currency, price, rating_count_tot, rating_count_ver, user_rating, user_rating_ver, ver, cont_rating, prime_genre, sup_devices.num, ipadSc_urls.num, lang.num, vpp_lic]
# Index: []

# %%
n=m.values[:,1]
# Out:
# array([3.99, 0.0, 0.0, ..., 1.99, 0.0, 0.0], dtype=object)

# %%
AppleStore.groupby(['price']).mean().filter(items=['price','user_rating']).values[0]
# Out:
# array([3.37672584])

# %% [markdown]
# Problem Set
# App Store Dataset
#
# - List of all unique Prime_Genres(categories) in the dataset
# - Category with highest number of apps
# - Category with lowest number of apps
# - Category with highest user rating
# - App with highest downloads
# Category with highest average rating count
# Average user rating for free apps
# Average user rating for paid apps
# Category with highest average user rating for paid apps
# - Most frequent Price point > 0
# Compare average user rating for paid vs free gaming apps
